# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
from pandas import read_csv
import pyodbc
from sqlalchemy import create_engine,text
from bokeh.plotting import figure
from bokeh.embed import file_html
from bokeh.plotting import figure,output_file,save, show
from bokeh.models import HoverTool
from bokeh.layouts import column, row
from bokeh.models import Spinner

# %%
data = read_csv("2021-all-meter.csv",index_col=0)

# %%
data.head()
# Out:
#           AMI Meter ID                 date  16335457  18762999  230156289  \
# 0  2021-03-21 00:00:00  2021-03-21 00:30:00   104.192    28.649      46.68
# 1  2021-03-21 00:30:00  2021-03-21 01:00:00   104.848    28.578      51.60
# 2  2021-03-21 01:00:00  2021-03-21 01:30:00   106.160    29.929      55.29
# 3  2021-03-21 01:30:00  2021-03-21 02:00:00   104.192    29.488      50.37
# 4  2021-03-21 02:00:00  2021-03-21 02:30:00   104.192    28.645      52.83
#
#    56068032  56073008  56210792  56464971  66675284  ...  98828750  98923621  \
# 0    13.104     9.195    373.44    19.656     5.491  ...    20.640     0.324
# 1    15.728     9.810    373.44    20.640     6.278  ...    21.624     0.324
# 2    14.416     8.580    375.96    19.656     7.853  ...     9.338     0.160
# 3    16.384    11.040    378.36    18.672     6.278  ...     9.418     0.324
# 4    15.728    12.270    375.96    20.640     4.704  ...     8.928     0.324
#
#    98923641  98923648  98923655  98923661  98923662  98923663  Residential  \
# 0    15.228    16.212    47.430     51.60     16.35    21.624    67808.216
# 1    14.736    15.228    39.198     46.68     16.35    17.688    67808.216
# 2    15.228    14.244    40.976     44.22     14.30    18.180    68586.253
# 3    14.736    14.244    42.165     44.22     16.35    16.704    68586.253
# 4    15.228    16.212    50.782     46.68     18.40    18.180    71152.560
#
#        Total
# 0  71482.267
# 1  71395.502
# 2  72266.724
# 3  72069.140
# 4  74632.641
#
# [5 rows x 55 columns]

# %%
ar = []
for i in range(0,data.shape[0],1):
    for c in data.select_dtypes(include=np.number).columns:
        ar.append([c,data.iloc[[i]]["AMI Meter ID"].values[0], data.iloc[[i]]["date"].values[0], int(data.iloc[[i]][c].values)])

SQLData = pd.DataFrame(ar)

# %%
SQLData.rename(columns = {0:"meter_name", 1:"start_time",2:"end_time", 3:"value"}, inplace = True)

# %%
SQLData.head()
# Out:
#   meter_name           start_time             end_time  value
# 0   16335457  2021-03-21 00:00:00  2021-03-21 00:30:00    104
# 1   18762999  2021-03-21 00:00:00  2021-03-21 00:30:00     28
# 2  230156289  2021-03-21 00:00:00  2021-03-21 00:30:00     46
# 3   56068032  2021-03-21 00:00:00  2021-03-21 00:30:00     13
# 4   56073008  2021-03-21 00:00:00  2021-03-21 00:30:00      9

# %%
SQLData.shape
# Out:
# (445200, 4)

# %%
# IMPORT THE SQALCHEMY LIBRARY's CREATE_ENGINE METHOD


# DEFINE THE DATABASE CREDENTIALS
user = 'root'
password = 'NewPassword'
host = '127.0.0.1'
port = 3306
database = 'demand_response_portal'

# PYTHON FUNCTION TO CONNECT TO THE MYSQL DATABASE AND
# RETURN THE SQLACHEMY ENGINE OBJECT
def get_connection():
    return create_engine(
        url="mysql://{0}:{1}@{2}:{3}/{4}".format(
            user, password, host, port, database
        )
    )

#pyodbc.
#if __name__ == '__main__':
engine = []

# GET THE CONNECTION OBJECT (ENGINE) FOR THE DATABASE
engine = get_connection()
conn = engine.connect()

# %%
SQLData.to_sql('meter_data', con=engine, if_exists='replace')

# %%
query = text("select meter_data.value as power, meter_data.start_time as start from meter_data where meter_data.meter_name = 'Total'")
GetSQLTest = pd.read_sql_query(query,conn)

# %%
display(GetSQLTest)
print(GetSQLTest["power"].values)
# Out:
#       power                start
# 0     71482  2021-03-21 00:00:00
# 1     71395  2021-03-21 00:30:00
# 2     72266  2021-03-21 01:00:00
# 3     72069  2021-03-21 01:30:00
# 4     74632  2021-03-21 02:00:00
# ...     ...                  ...
# 8395  76780  2021-09-27 21:30:00
# 8396  65924  2021-09-27 22:00:00
# 8397  65741  2021-09-27 22:30:00
# 8398  54984  2021-09-27 23:00:00
# 8399  55102  2021-09-27 23:30:00
#
# [8400 rows x 2 columns]
# [71482 71395 72266 ... 65741 54984 55102]

# %%
GetSQLTest['start'] =  pd.to_datetime(GetSQLTest['start'], format='%Y-%m-%d %H:%M:%S')
GetSQLTest["sd"] = GetSQLTest['start'].dt.date.copy()
GetSQLTest['sm'] = [s.replace(day=1) for s in GetSQLTest['start'].dt.date].copy()

# %%
GetSQLTest.head()
# Out:
#    power               start          sd          sm
# 0  71482 2021-03-21 00:00:00  2021-03-21  2021-03-01
# 1  71395 2021-03-21 00:30:00  2021-03-21  2021-03-01
# 2  72266 2021-03-21 01:00:00  2021-03-21  2021-03-01
# 3  72069 2021-03-21 01:30:00  2021-03-21  2021-03-01
# 4  74632 2021-03-21 02:00:00  2021-03-21  2021-03-01

# %%
(
    GetSQLTest[["sm","sd","power"]].groupby(["sm","sd"],as_index = False).sum().query("sm == @m")[["sd","power"]]
).head(10)
# Out:
#            sd    power
# 0  2021-03-21  3723869
# 1  2021-03-22  3123780
# 2  2021-03-23  2850371
# 3  2021-03-24  2871810
# 4  2021-03-25  2665381
# 5  2021-03-26  2597496
# 6  2021-03-27  2826155
# 7  2021-03-28  2898445
# 8  2021-03-29  3540989
# 9  2021-03-30  3175540

# %%
Annual = GetSQLTest[["sm","power"]].groupby('sm',as_index = False).sum()
fig = figure(title = "Total Line Graph",x_axis_type = "datetime")
fig2=fig.square(source = Annual,x="sm",y="power",size = 20,color='red')
fig1 = fig.line(source = Annual,x="sm",y="power",line_width = 2,color='red')
hover = HoverTool(tooltips=[('Timestamp', '@sm{%m-%d-%Y}'), ('power',"@power")],formatters={'@sm': 'datetime'},)
fig.add_tools(hover)
callback = CustomJS(args=dict(p=p), code="""
                      var a = cb_obj.value;
                      p.x_range = a;
                      p.change.emit();
                      """)

range_slider = from bokeh.models.widgets import DateRangeSlider
range_slider.js_on_change('value', callback)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [88], line 8
#       6 fig.add_tools(hover)
#       7 spinner = Spinner(title="Glyph size", low=1, high=40, step=0.5, value=20, width=80)
# ----> 8 spinner.js_link('value', fig.x_axis, 'size')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bokeh\core\has_props.py:264, in HasProps.__getattr__(self, name)
#     261 if isinstance(descriptor, property): # Python property
#     262     return super().__getattr__(name)
# --> 264 self._raise_attribute_error_with_matches(name, properties)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bokeh\core\has_props.py:272, in HasProps._raise_attribute_error_with_matches(self, name, properties)
#     269 if not matches:
#     270     matches, text = sorted(properties), "possible"
# --> 272 raise AttributeError(f"unexpected attribute {name!r} to {self.__class__.__name__}, {text} attributes are {nice_join(matches)}")
#
# AttributeError: unexpected attribute 'x_axis' to Figure, possible attributes are above, align, aspect_ratio, aspect_scale, background, background_fill_alpha, background_fill_color, below, border_fill_alpha, border_fill_color, center, css_classes, disabled, extra_x_ranges, extra_x_scales, extra_y_ranges, extra_y_scales, frame_height, frame_width, height, height_policy, hidpi, inner_height, inner_width, js_event_callbacks, js_property_callbacks, left, lod_factor, lod_interval, lod_threshold, lod_timeout, margin, match_aspect, max_height, max_width, min_border, min_border_bottom, min_border_left, min_border_right, min_border_top, min_height, min_width, name, outer_height, outer_width, outline_line_alpha, outline_line_cap, outline_line_color, outline_line_dash, outline_line_dash_offset, outline_line_join, outline_line_width, output_backend, plot_height, plot_width, renderers, reset_policy, right, sizing_mode, subscribed_events, syncable, tags, title, title_location, toolbar, toolbar_location, toolbar_sticky, visible, width, width_policy, x_range, x_scale, y_range or y_scale

# %%
m = GetSQLTest["sm"].unique()[0]
Month = GetSQLTest[["sm","sd","power"]].groupby(["sm","sd"],as_index = False).sum().query("sm == @m")[["sd","power"]]
pig = figure(title = "Total Month Line Graph",x_axis_type = "datetime")
pig1 = pig.line(source = Month,x="sd",y="power",line_width = 2,color='navy')
pig.add_tools(HoverTool(renderers=[pig1], tooltips=[('power',"@power")],mode='vline'))

# %%
d = GetSQLTest["sd"].unique()[0]
Daily = GetSQLTest[['start',"sd","power"]].query("sd == @d")[["start", "power"]]
dig = figure(title = "Total Day Line Graph",x_axis_type = "datetime")
dig1 = dig.line(source = Daily,x="start",y="power",line_width = 2,color='navy')
dig.add_tools(HoverTool(renderers=[dig1], tooltips=[('power',"@power")],mode='vline'))

# %%
show(row(column(fig),spinner))

# %%
from bokeh.layouts import column,row
from bokeh.models import CustomJS, ColumnDataSource, Slider
from bokeh.plotting import figure, output_file, show

output_file("callback.html")

x = [x*0.005 for x in range(0, 200)]
y = x

source = ColumnDataSource(data=dict(x=x, y=y))

plot = figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
        var data = source.get('data');
        var f = cb_obj.get('value')
        x = data['x']
        y = data['y']
        for (i = 0; i < x.length; i++) {
            y[i] = Math.pow(x[i], f)
        }
        source.trigger('change');
    """)

slider = Slider(start=0.1, end=4, value=1, step=.1, title="power", callback=callback)

layout = column(slider, plot)

show(layout)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [25], line 26
#      13 plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)
#      15 callback = CustomJS(args=dict(source=source), code="""
#      16         var data = source.get('data');
#      17         var f = cb_obj.get('value')
#    (...)
#      23         source.trigger('change');
#      24     """)
# ---> 26 slider = Slider(start=0.1, end=4, value=1, step=.1, title="power", callback=callback)
#      28 layout = column(slider, plot)
#      30 show(layout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bokeh\models\widgets\sliders.py:80, in AbstractSlider.__init__(self, **kwargs)
#      77 if "value" in kwargs and "value_throttled" not in kwargs:
#      78     kwargs["value_throttled"] = kwargs["value"]
# ---> 80 super().__init__(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bokeh\model\model.py:128, in Model.__init__(self, **kwargs)
#     121 def __init__(self, **kwargs: Any) -> None:
#     122
#     123     # "id" is popped from **kw in __new__, so in an ideal world I don't
#     124     # think it should be here too. But Python has subtle behavior here, so
#     125     # it is necessary
#     126     kwargs.pop("id", None)
# --> 128     super().__init__(**kwargs)
#     129     default_theme.apply_to_model(self)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bokeh\core\has_props.py:206, in HasProps.__init__(self, **properties)
#     203 self._unstable_themed_values = {}
#     205 for name, value in properties.items():
# --> 206     setattr(self, name, value)
#     208 self._initialized = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bokeh\core\has_props.py:236, in HasProps.__setattr__(self, name, value)
#     233 if isinstance(descriptor, property): # Python property
#     234     return super().__setattr__(name, value)
# --> 236 self._raise_attribute_error_with_matches(name, properties)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bokeh\core\has_props.py:272, in HasProps._raise_attribute_error_with_matches(self, name, properties)
#     269 if not matches:
#     270     matches, text = sorted(properties), "possible"
# --> 272 raise AttributeError(f"unexpected attribute {name!r} to {self.__class__.__name__}, {text} attributes are {nice_join(matches)}")
#
# AttributeError: unexpected attribute 'callback' to Slider, similar attributes are js_event_callbacks
